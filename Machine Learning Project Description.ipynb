# %% [markdown]
# **사업 계획서(팀만의 가치를 찾는 작업이 필수)**
#  - 능력 발휘 120%정도
# 1. 내가 할 주제
# 2. 주제의 소개
#  - 로컬 시장 규모
#  - 글로벌 시장 규모
#  - 1, 2, 3등 회사
# 3. 머신러닝을 진행한 후 매출에 기여할 기대 효과
#  - 영향을 미칠 수 있는 가능성
# 4. raw data의 간단한 분석
# 5. crawling해도 괜찮고,
#  - kaggle data도 괜찮으나, 케글을 사용할 경우, kernal과는 다른 특징을 찾아야 함

# %% [markdown]
# **1. 주제**
# - 그림체 분류
# - 웹툰 내부의 상품과 유사한 실제제품 추천

# %% [markdown]
# **2. 주제의 소개**
# - 1) 그림체가 비슷한 웹툰으로 분류 진행
#     - KMeans clustering
# - 2) 그림체가 비슷한 애니메이션 추천 진행
#     - 라프텔 등
# - 3) 웹 사이트로 서비스 구현
#     - 웹툰 이미지를 넣으면 비슷한 그림체의 웹툰과 애니매이션을 찾아줌
#
# **추가 목표**
# - 4) 그림체별 유저의 성향 파악
#     - 그림체만으로 어떻게 유저의 성향을 파악할 수 있는지 확인 필요
# - 5) 웹툰 내부의 상품과 유사한 실제 제품을 추천
#     - 웹툰 이미지를 구글, 카카오 api로 분석해서 나온 단어들을 쇼핑몰 키워드에 연결하는 방식

# %% [markdown]
# **웹툰 로컬 시장 규모**
# - 2019년
#     - 에니메이션 0.7조원
#     - 만화 1.2조원

# %%
from IPython.display import Image
Image("./domestic.jpg") # code안에서 나오게 할 때

# %% [markdown]
# **웹툰 글로벌 시장 규모**

# %%
Image("./world.jpg")

# %% [markdown]
# **웹툰 국내 메이저 회사**
# - 2018년 기준 순이익
#     - 네이버 웹툰 : -627억
#     - 카카오 페이지 : -42억

# %%
Image("./company.jpeg")

# %% [markdown]
# **3. 머신러닝을 진행한 후 매출에 기여할 기대 효과**
# - 매출 다각화 및 여러 분야의 매출 증대 효과 발생 예상
#     - 웹툰 작가
#     - 웹툰 업체
#     - 의류 업체
#     - 미용 업체
#     - 인테리어 업체
#     - 익스테리어 업체

# %% [markdown]
# **매출 계획**
# - 소셜커머스(쿠팡, 위메프, 티몬)업체 혹은 있다면 의류대여업체 등과 조인하여 판매 및 구독서비스 진행
