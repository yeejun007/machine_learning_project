# %% [markdown]
# ## 네이버 베스트 댓글 분석
# - 네이버 웹툰 325개의 댓글 모음들을 벡터화 시켜서 준비하기
# - input으로 넣을 다음 웹툰의 댓글 넣고,
# - 네이버의 어떤 웹툰이랑 가장 가까운지 확인하기

# %%
comment_df = pd.read_csv('./comments_df_yj.csv').drop(columns='Unnamed: 0')
comment_df.tail(1)
# Out:
#             title weekday  last                     content      genre  age  \
# 324  스퍼맨: 현자단의 역습     sun    44  스퍼맨이 돌아왔다! 근데 현자가 되어 돌아왔다!  에피소드, 드라마   18
#
#                                               comments
# 324  |||헷갈리는 분들 계신데 시즌2는 수위가 너무 쌔서 정식 연재는 못하고 네이버시리...

# %%
# 특수문자 제거함수

import re

def preprocessing(sentence):
    sentence =re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', sentence)
    return sentence

# comment_df['content_cleaned'] = comment_df['contents'].apply(preprocessing)

# %%
comment_df
# Out:
#             title weekday  last  \
# 0            신의 탑     mon   479
# 1          윈드브레이커     mon   308
# 2            인생존망     mon    25
# 3          소녀의 세계     mon   216
# 4          평범한 8반     mon   306
# ..            ...     ...   ...
# 320   헬퍼 2 : 킬베로스     wed   223
# 321          사냥개들     fri    52
# 322          토끼대왕     sat     7
# 323          압락사스     sat    39
# 324  스퍼맨: 현자단의 역습     sun    44
#
#                                                content      genre  age  \
# 0        자신의 모든 것이었던 소녀를 쫓아 탑에 들어온 소년그리고 그런 소년을 시험하는 탑   스토리, 판타지   12
# 1                              자유를 꿈꾸는 청춘들의 스트릿라이딩 드라마   스토리, 스포츠   12
# 2    학교 다닐때 그렇게 놀았으면, 졸업하고 지금은 불행해야하는거 아니야?너 때문에 망한...   에피소드, 액션   15
# 3    완벽해 보이지만 사실 외로웠던 백조들과 맘씨 착한 오리가 만나여러 갈등을 함께 겪으...   스토리, 드라마    0
# 4               안 평범한 아이들이 모인 평범한 8반고품격 웰메이드 병맛을 느껴보세요   스토리, 드라마   15
# ..                                                 ...        ...  ...
# 320       역시는 역시 역시군.킬베로스 트라이브의 대장 장광남이 펼치는 스트릿 액션 만화.    스토리, 액션   18
# ...

# %%
# comment_df['comments'][0]

# %%
from konlpy.tag import Okt
t = Okt()

# %%
# 웹툰 제목과 댓글 모음들을 리스트에 순서대로 모으기

title_list = list(comment_df['title'])
comment_list = list(comment_df['comments'])
comment_list = [each_comments[3:].split("|||") for each_comments in comment_list]
comment_list[1]
# Out:
# ['윈드브레이커 환영하시는분들 좋아요 한번씩만 부탁드립니다',
#  '대작의 스멜이 아니라 대작이다.  제군들 좋아요 눌러서 내일시험 잘보자',
#  '니네 베도에서 윈드봇봤지 그럼들어온순간 한번보는게아니라 쭉봐라 진짜 장담하는데 내개인적으로 네이버 어떤 스포츠웹툰보다 이게 탑오브탑이다 레알 웹툰오신거 사랑해요 작가님 딴놈들은 더게이머 연애혁명 같은거 기달렸을지몰라도 전 윈브만 기달렸어요',
#  '하 베도서 프리드로우와 쌍두마차였던 윈브가 드디어!!!!!빨리 위쪽으로 꺼져요 스크롤내리는동안 현기증나요',
#  '내일 입대합니다 대한민국 잘 지키고 오겠습니다 !!',
#  '이게 바로 스포츠 웹툰의 정석이다',
#  '처음이만화를 본사람은 메이플에 시그너스 궁수 캐릭인줄알겠지',
#  '이 웹툰으로 인해서 자전거 도로가 확장 되었으면 좋겟다.',
#  '월요웹툰에 또다른 전설이 시작되는구나....',
#  '아나 월요일에 봐야될 웹툰하나 또생겻네',
#  '자전거 솔로부대 : 이 웹툰을 보고 자전거 타는 여자들이 늘었으면 좋겠다..',
#  '위로 꺼지라니 ㅡㅡ천상계로 황금마차태워 모셔라',
#  '보통 첫화 보면 전설의 시작 이러면 베댓되던데 나도 해봄 ㅋㅋ 전설의 시작',
#  '와 요즘 네이버가 대작이 될 웹툰 드럽게 잘 뽑네;;;',
#  '구석구석 도전해봅니다.',
#  '와 진심 이걸 보면서 느낀게 우선 리메이크를 거치면서 베도때와 달라졌다는점그리고 이웹툰을 베도에서 보면서 자전거에 관심이 생겼고 그후 정식웹툰에서 다시보니 느끼는 바가 다르다는점윈드브레이커 정말 기대작  아니 대작입니다.',
#  '주인공 자전거 타이어 터진거 같은데..... 진심 대작나무 타는 냄세나서.... 내가 하나 사주고 싶네. 베뎃가면 자전거 한대 사준다.',
#  '일섬님이 자전거 사주시면 전 윈드브레이크를 영화화 시키겟습니다',
#  '어릿광대님 볼수있도록 베뎃좀 부탁드립니다. 안녕하세요? 일섬입니다. 자전거 사줄태니까 영화내십쇼. 저는 3발자전거 드리겠습니다.',
# ...

# %%
comment_list[1][0]
# Out:
# '윈드브레이커 환영하시는분들 좋아요 한번씩만 부탁드립니다'

# %%
t.morphs(comment_list[1][0])
# Out:
# ['윈드브레이커', '환영', '하시는', '분', '들', '좋아요', '한번', '씩', '만', '부탁드립니다']

# %%
arr = []

for each_comments in comment_list:
    sum = ''

# %%
contents_for_vectorize = []

for content in contents_tokens:
    sentence = ''
    for word in content:
        sentence = sentence + ' ' + word
        
    contents_for_vectorize.append(sentence)

contents_for_vectorize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=1, decode_error='ignore')
